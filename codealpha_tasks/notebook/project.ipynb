# %%
import pandas as pd

# %%
df = pd.read_csv("../data/quotes.csv")

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\pavan\OneDrive\Desktop\DataAnalyticsProject\notebook

# %%
import os
print(os.listdir("../data"))
# Out:
# ['quotes.csv']

# %%
import pandas as pd

df = pd.read_csv("../data/quotes.csv")

df.head()
# Out:
#                                                Quote
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# 4  “Imperfection is beauty, madness is genius and...

# %%
import matplotlib.pyplot as plt

df["Length"] = df["Quote"].apply(len)

plt.hist(df["Length"])
plt.title("Quote Length Distribution")
plt.show()

# %%
from textblob import TextBlob

# %%
def sentiment(text):

    score = TextBlob(text).sentiment.polarity

    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Quote"].apply(sentiment)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df["Sentiment"] = df["Quote"].apply(sentiment)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/quotes.csv")

# %%
df.head()
# Out:
#                                                Quote
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# 4  “Imperfection is beauty, madness is genius and...

# %%
from textblob import TextBlob

# %%
def sentiment(text):
    score = TextBlob(text).sentiment.polarity

    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Quote"].apply(sentiment)

# %%
df.head()
# Out:
#                                                Quote
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# 4  “Imperfection is beauty, madness is genius and...

# %%
df.columns
# Out:
# Index(['Quote'], dtype='object')

# %%
df["Sentiment"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pavan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.columns
# Out:
# Index(['Quote'], dtype='object')

# %%
from textblob import TextBlob

# %%
def sentiment(text):
    score = TextBlob(text).sentiment.polarity

    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Quote"].apply(sentiment)

# %%
df.columns
# Out:
# Index(['Quote', 'Sentiment'], dtype='object')

# %%
df.head()
# Out:
#                                                Quote Sentiment
# 0  “The world as we have created it is a process ...   Neutral
# 1  “It is our choices, Harry, that show what we t...  Positive
# 2  “There are only two ways to live your life. On...  Positive
# 3  “The person, be it gentleman or lady, who has ...  Negative
# 4  “Imperfection is beauty, madness is genius and...  Negative

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Positive    6
# Neutral     2
# Negative    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(kind="bar")

plt.title("Sentiment Analysis")

plt.show()
